# %% [markdown]
# <a href="https://colab.research.google.com/github/Sreenavya04/Competitive-programming/blob/main/ass_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def max_meetings(meetings):
    meetings.sort(key=lambda x: x[1])
    count = 0
    last_end = -1

    for start, end in meetings:
        if start >= last_end:   # allow equal start time
            count += 1
            last_end = end
    return count


T = int(input().strip())
for _ in range(T):
    N = int(input().strip())
    meetings = []
    for _ in range(N):
        Si, Ei = map(int, input().split())
        meetings.append((Si, Ei))
    print(max_meetings(meetings))
# Out:
# 1
# 3
# 1 3
# 2 4
# 3 5
# 2
